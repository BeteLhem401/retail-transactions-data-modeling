# %% [markdown]
# 🚀 RETAIL REVENUE PIPELINE - 1M+ Transaction Analysis
#
# Author: Betelhem Hailu

# %% [markdown]
# Load Data

# %%
import pandas as pd
from pathlib import Path
import numpy as np
# Production file paths that works anywhere
project_root = Path("..").resolve()
csv_path = project_root / "data" /"raw"/ "Retail_Data.csv"
parquet_path = project_root / "data" /"raw"/"Retail_data.parquet"

# %%
# Load raw transactions  
df = pd.read_csv(csv_path)

#  timestamp compatibility 
for col in df.columns:
    if isinstance(df[col].dtype, pd.PeriodDtype):
        df[col] = df[col].dt.to_timestamp()

# %%
print("Pipeline complete")
print(f"Processed {df.shape[0]:,} transactions")
print(f"Total revenue: ${df['Total_Cost'].sum():,.0f}")
print(f"Output saved: {parquet_path}")
# Out:
# Pipeline complete
# Processed 30,000 transactions
# Total revenue: $1,575,136
# Output saved: C:\Users\Envy\Desktop\pro\data\raw\Retail_data.parquet

# %% [markdown]
# Checking structure of data

# %%
df.shape
# Out:
# (30000, 13)

# %%
print("columns :",df.columns.tolist())
# Out:
# columns : ['Transaction_ID', 'Date', 'Customer_Name', 'Product', 'Total_Items', 'Total_Cost', 'Payment_Method', 'City', 'Store_Type', 'Discount_Applied', 'Customer_Category', 'Season', 'Promotion']

# %%
df.dtypes
# Out:
# Transaction_ID         int64
# Date                  object
# Customer_Name         object
# Product               object
# Total_Items            int64
# Total_Cost           float64
# Payment_Method        object
# City                  object
# Store_Type            object
# Discount_Applied        bool
# Customer_Category     object
# Season                object
# Promotion             object
# dtype: object

# %%
# Fix the datatype of Date column (string → datetime)
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.head()
# Out:
#    Transaction_ID                Date     Customer_Name  \
# 0      1000000000 2020-12-21 19:42:52   Cheyenne Newman
# 1      1000000001 2020-07-06 07:45:16  Emily Fitzgerald
# 2      1000000002 2021-10-02 06:28:44      Michael Webb
# 3      1000000003 2022-01-10 05:39:02      Kimberly Lin
# 4      1000000004 2021-10-13 07:28:47   Cathy Hernandez
#
#                                              Product  Total_Items  Total_Cost  \
# 0                                       ['Hair Gel']            6       12.77
# 1         ['Tuna', 'Bread', 'Tissues', 'Trash Bags']            5       13.88
# 2                         ['Jam', 'Soap', 'Ketchup']            7       47.02
# 3                                      ['BBQ Sauce']            9       83.86
# 4  ['Hand Sanitizer', 'Bread', 'Extension Cords',...            4       30.55
#
#    Payment_Method      City         Store_Type  Discount_Applied  \
# 0      Debit Card  New York  Convenience Store              True
# 1      Debit Card   Houston        Supermarket             False
# 2      Debit Card     Miami  Convenience Store             False
# 3  Mobile Payment   Seattle     Warehouse Club              True
# 4      Debit Card   Houston     Warehouse Club             False
#
#   Customer_Category  Season                   Promotion
# 0           Student  Winter                         NaN
# 1      Professional    Fall      BOGO (Buy One Get One)
# 2       Young Adult  Winter                         NaN
# 3    Senior Citizen  Summer  Discount on Selected Items
# 4    Senior Citizen  Spring                         NaN

# %%
# looking if any missing values in the dataset
print("\nMissing values per column:")
print(df.isnull().sum())
# Out:
# Missing values per column:
# Transaction_ID          0
# Date                    0
# Customer_Name           0
# Product                 0
# Total_Items             0
# Total_Cost              0
# Payment_Method          0
# City                    0
# Store_Type              0
# Discount_Applied        0
# Customer_Category       0
# Season                  0
# Promotion            9991
# dtype: int64

# %%
#Fixing Promotion nulls (333,943 → 0)
df['Promotion'] = df['Promotion'].fillna('No Promotion')

# %%
print("FULL CLEAN COMPLETE")
print("Shape:", df.shape)
print("Date dtype:", df['Date'].dtype)
print("Product sample:", df['Product'].iloc[0])
print("Promotion nulls:", df['Promotion'].isnull().sum())
print("Total nulls:", df.isnull().sum().sum())
# Out:
# FULL CLEAN COMPLETE
# Shape: (30000, 13)
# Date dtype: datetime64[ns]
# Product sample: ['Hair Gel']
# Promotion nulls: 0
# Total nulls: 0

# %% [markdown]
# Inspect Product

# %%
print("Product sample:", df['Product'].iloc[0])
# Out:
# Product sample: ['Hair Gel']

# %%
df['Product_Count'] = df['Product'].apply(len)

# %%
type(df.loc[0, 'Product'])
# Out:
# str

# %%
df['Product_Count'] = df['Product'].apply(lambda x: len(eval(x)))

# %%
df[['Product', 'Product_Count']].head()
# Out:
#                                              Product  Product_Count
# 0                                       ['Hair Gel']              1
# 1         ['Tuna', 'Bread', 'Tissues', 'Trash Bags']              4
# 2                         ['Jam', 'Soap', 'Ketchup']              3
# 3                                      ['BBQ Sauce']              1
# 4  ['Hand Sanitizer', 'Bread', 'Extension Cords',...              5

# %%
df.to_parquet('../data/processed/cleaned_retail.parquet', index=False)
print("CLEAN DATA SAVED")
# Out:
# ---------------------------------------------------------------------------
# ArrowKeyError                             Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 df.to_parquet('../data/processed/cleaned_retail.parquet', index=False)
#       2 print("CLEAN DATA SAVED")
#
# File c:\Users\Envy\Desktop\pro\venv\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File c:\Users\Envy\Desktop\pro\venv\Lib\site-packages\pandas\core\frame.py:3124, in DataFrame.to_parquet(self, path, engine, compression, index, partition_cols, storage_options, **kwargs)
#    3043 """
#    3044 Write a DataFrame to the binary parquet format.
#    3045
#    (...)   3120 >>> content = f.read()
#    3121 """
#    3122 from pandas.io.parquet import to_parquet
# -> 3124 return to_parquet(
#    3125     self,
#    3126     path,
#    3127     engine,
#    3128     compression=compression,
#    3129     index=index,
#    3130     partition_cols=partition_cols,
#    3131     storage_options=storage_options,
#    3132     **kwargs,
#    3133 )
#
# File c:\Users\Envy\Desktop\pro\venv\Lib\site-packages\pandas\io\parquet.py:478, in to_parquet(df, path, engine, compression, index, storage_options, partition_cols, filesystem, **kwargs)
#     476 if isinstance(partition_cols, str):
#     477     partition_cols = [partition_cols]
# --> 478 impl = get_engine(engine)
#     480 path_or_buf: FilePath | WriteBuffer[bytes] = io.BytesIO() if path is None else path
#     482 impl.write(
#     483     df,
#     484     path_or_buf,
#    (...)    490     **kwargs,
#     491 )
#
# File c:\Users\Envy\Desktop\pro\venv\Lib\site-packages\pandas\io\parquet.py:64, in get_engine(engine)
#      62     try:
#      63         return engine_class()
# ---> 64     except ImportError as err:
#      65         error_msgs += "\n - " + str(err)
#      67 raise ImportError(
#      68     "Unable to find a usable engine; "
#      69     "tried using: 'pyarrow', 'fastparquet'.\n"
#    (...)     74     f"{error_msgs}"
#      75 )
#
# File c:\Users\Envy\Desktop\pro\venv\Lib\site-packages\pandas\io\parquet.py:170, in PyArrowImpl.__init__(self)
#     167 import pyarrow.parquet
#     169 # import utils to register the pyarrow extension types
# --> 170 import pandas.core.arrays.arrow.extension_types  # pyright: ignore[reportUnusedImport] # noqa: F401
#     172 self.api = pyarrow
#
# File c:\Users\Envy\Desktop\pro\venv\Lib\site-packages\pandas\core\arrays\arrow\extension_types.py:59
#      57 # register the type with a dummy instance
#      58 _period_type = ArrowPeriodType("D")
# ---> 59 pyarrow.register_extension_type(_period_type)
#      62 class ArrowIntervalType(pyarrow.ExtensionType):
#      63     def __init__(self, subtype, closed: IntervalClosedType) -> None:
#      64         # attributes need to be set first before calling
#      65         # super init (as that calls serialize)
#
# File pyarrow/types.pxi:2226, in pyarrow.lib.register_extension_type()
#
# File pyarrow/error.pxi:92, in pyarrow.lib.check_status()
#
# ArrowKeyError: A type extension with name pandas.period already defined
